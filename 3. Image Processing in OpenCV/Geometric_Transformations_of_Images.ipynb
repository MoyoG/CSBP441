# %% [markdown]
# Import libraries

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %% [markdown]
# Translation

# %%
img = cv.imread('../images/messi5.jpg', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
rows,cols = img.shape
M = np.float32([[1,0,100],[0,1,50]])
dst = cv.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.axis('off'),plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB)),plt.title('original')
plt.subplot(122),plt.axis('off'),plt.imshow(cv.cvtColor(dst, cv.COLOR_BGR2RGB)),plt.title('translated')
plt.show()

# %% [markdown]
# Rotation

# %%
img = cv.imread('../images/messi5.jpg', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
rows,cols = img.shape
# cols-1 and rows-1 are the coordinate limits.
M = cv.getRotationMatrix2D(((cols-1)/2.0,(rows-1)/2.0),90,1)
dst = cv.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.axis('off'),plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB)),plt.title('original')
plt.subplot(122),plt.axis('off'),plt.imshow(cv.cvtColor(dst, cv.COLOR_BGR2RGB)),plt.title('rotated')
plt.show()

# %% [markdown]
# Affine Transformation

# %%
img = cv.imread('../images/drawing.jpg')
assert img is not None, "file could not be read, check with os.path.exists()"
rows,cols,ch = img.shape
pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[100,100],[200,50],[100,150]])
M = cv.getAffineTransform(pts1,pts2)
dst = cv.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.axis("off"),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.axis('off'),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# Perspective Transformation

# %%
img = cv.imread('../images/sudoku.png')
assert img is not None, "file could not be read, check with os.path.exists()"
rows,cols,ch = img.shape
pts1 = np.float32([[56,65],[366,51],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M = cv.getPerspectiveTransform(pts1,pts2)
dst = cv.warpPerspective(img,M,(300,300))
plt.subplot(121),plt.axis("off"),plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB)),plt.title('Input')
plt.subplot(122),plt.axis('off'),plt.imshow(cv.cvtColor(dst, cv.COLOR_BGR2RGB)),plt.title('Output')
plt.show()
